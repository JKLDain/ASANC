# %%
import os
import pandas as pd
import librosa
import librosa as lr
import sklearn
import numpy as np
from glob import glob

# %% [markdown]
# ## wav file load

# %%
data_dir = 'C:/Users/jayjo/Desktop/data'
wav_files = glob(data_dir + '/*.wav')
filename = os.listdir(data_dir)

# %%
filename
# Out:
# ['Car horn (1).wav',
#  'Car horn (10).wav',
#  'Car horn (11).wav',
#  'Car horn (12).wav',
#  'Car horn (13).wav',
#  'Car horn (14).wav',
#  'Car horn (15).wav',
#  'Car horn (16).wav',
#  'Car horn (17).wav',
#  'Car horn (18).wav',
#  'Car horn (19).wav',
#  'Car horn (2).wav',
#  'Car horn (20).wav',
#  'Car horn (21).wav',
#  'Car horn (22).wav',
#  'Car horn (23).wav',
#  'Car horn (24).wav',
#  'Car horn (25).wav',
#  'Car horn (26).wav',
#  'Car horn (27).wav',
#  'Car horn (28).wav',
#  'Car horn (29).wav',
#  'Car horn (3).wav',
#  'Car horn (30).wav',
#  'Car horn (31).wav',
#  'Car horn (32).wav',
#  'Car horn (33).wav',
#  'Car horn (34).wav',
#  'Car horn (35).wav',
#  'Car horn (36).wav',
#  'Car horn (37).wav',
#  'Car horn (38).wav',
#  'Car horn (39).wav',
#  'Car horn (4).wav',
#  'Car horn (40).wav',
#  'Car horn (41).wav',
#  'Car horn (42).wav',
#  'Car horn (43).wav',
#  'Car horn (44).wav',
#  'Car horn (45).wav',
#  'Car horn (46).wav',
# ...

# %% [markdown]
# ## Preprocessing

# %%
def trim_audio_data(audio_file,sr=16000,sec=1):
    
    # 오디오파일 1개를 입력한 sec로 나눠주는 함수 sr은 sampling rate, sec는 나눌 구간의 시간

    
    y, sr = librosa.load(audio_file, sr=sr)

    # 파일을 입력한 구간으로 나누기 전에 구간으로 나누어떨어지도록 남는 뒷부분을 버림

    ny = y[:len(y)-len(y)%(sr*sec)]

    # 한 행이 한 구간(sec * sr)인 넘파이 행렬로 변환
        
    ny=ny.reshape((-1, sr*sec))

    return ny

def prototype(audio_path,sr=16000,sec=1):
    
    # trim_audio_data함수를 for문으로 엮은 함수

    audio_list = os.listdir(audio_path)

    result=np.zeros((1,sr*sec));
    
    # audio_path내의 모든 wav파일을 for문으로 trim_audio_data함수에 넣어줌


    for audio_name in audio_list:
        if audio_name.find('wav') is not -1:
            audio_file = audio_path + '/' + audio_name
    
            assist=trim_audio_data(audio_file,sr,sec)
    
    # 구간으로 나눠진 파일(넘파이 행렬)은 result에 하나로 쌓음

            result=np.concatenate((result,assist));
    
    result=result[1:,:];
    
    return result

def Mel_S(vector,frame_length=0.025,frame_stride=0.010,sr=16000,n_y=101):

    # audio 행렬을 넣으면 mel spectogram으로 변환시켜주는 함수

    
    # wav_length = len(y)/sr
    input_nfft = int(round(sr*frame_length))
    input_stride = int(round(sr*frame_stride))

    S = librosa.feature.melspectrogram(y=vector, n_mels=n_y, n_fft=input_nfft, hop_length=input_stride)

    return S

def Logmel_S(vector,frame_length=0.025,frame_stride=0.010,sr=16000,n_y=101):

    # audio 행렬을 넣으면 log mel spectogram으로 변환시켜주는 함수
    # wav_length = len(y)/sr
    input_nfft = int(round(sr*frame_length))
    input_stride = int(round(sr*frame_stride))

    S = librosa.feature.melspectrogram(y=vector, n_mels=n_y, n_fft=input_nfft, hop_length=input_stride)
    S = librosa.power_to_db(S,ref=np.max)

    return S


def predata(vector,frame_length=0.025,frame_stride=0.010,sr=16000,n_y=101):
#결과값 저장할 빈 list함수 result 정의
    result=[]
    aa=len(vector)
    
   # prototype함수 결과로 나오는 행렬에서 한 행 = 한 구간이니 for문으로 매 행을 뽑아내서 Mel_S함수에 넣고 result 리스크에 저장

    for i in range(0,aa):
        assist_vector=vector[i,:]
        ex=Mel_S(assist_vector,frame_length,frame_stride,sr,n_y)
        result.append(ex)
    
    return result

    # predata의 입력은 prototype의 결과로 나온 넘파이 행렬이고 결과값은 list에 mel spectrogram벡터가 저장되어 나오게 됨

def log_mel_predata(vector,frame_length=0.025,frame_stride=0.010,sr=16000,n_y=101):

    # predata함수를 log_mel spectrogram을 뽑는 함수로 수정한 함수
    
    result=[]
    aa=len(vector)

    for i in range(0,aa):
        assist_vector=vector[i,:]
        ex=Logmel_S(assist_vector,frame_length,frame_stride,sr,n_y)
        result.append(ex)

    return result
# Out:
# <>:30: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:30: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-4-b892def9b5f8>:30: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if audio_name.find('wav') is not -1:

# %% [markdown]
# ### wav file cut by one second, sampling rate = 44100 , extracting log melspectrogram

# %%
carhorn=prototype('C:/Users/jayjo/Desktop/dataset/Car horn',44100,1);
carhorn_mel=log_mel_predata(carhorn,0.025,0.01,44100,101)

# %%
Siren=prototype('C:/Users/jayjo/Desktop/dataset/Siren',44100,1);
Siren_mel=log_mel_predata(Siren,0.025,0.01,44100,101)

# %%
noise=prototype('C:/Users/jayjo/Desktop/dataset/noise',44100,1);
noise_mel=log_mel_predata(noise,0.025,0.01,44100,101)

# %%
humanvoice=prototype('C:/Users/jayjo/Desktop/dataset/human voice',44100,1);
humanvoice_mel=log_mel_predata(humanvoice,0.025,0.01,44100,101)

# %%
all_mel_data = pd.DataFrame(columns=['mel'])
carhorn_mel_data = pd.DataFrame(columns=['mel'])
siren_mel_data = pd.DataFrame(columns=['mel'])
noise_mel_data = pd.DataFrame(columns=['mel'])
humanvoice_mel_data = pd.DataFrame(columns=['mel'])
carhorn_mel_data['mel'] = carhorn_mel
siren_mel_data['mel'] = Siren_mel
noise_mel_data['mel'] = noise_mel
humanvoice_mel_data['mel'] = humanvoice_mel
noise_mel_data = noise_mel_data.drop(index = [11938,20562,23821])
noise_mel_data.reset_index(drop = True, inplace = True)   
all_mel_data = pd.concat([all_mel_data,carhorn_mel_data,siren_mel_data,noise_mel_data,humanvoice_mel_data])
all_mel_data.reset_index(drop = True, inplace = True)
all_mel_data
# Out:
#                                                      mel
# 0      [[-10.083232352986382, -10.016546102796235, -6...
# 1      [[-16.3515616053921, -18.426080528278487, -20....
# 2      [[-8.399666454074698, -5.967452692179485, -9.4...
# 3      [[-5.448152662433841, -0.19249003894980632, -1...
# 4      [[-19.898003755072065, -10.72434126598628, -7....
# ...                                                  ...
# 28379  [[-56.355110085886366, -56.853775876563034, -5...
# 28380  [[-19.514837053786223, -26.77858532778047, -28...
# 28381  [[-75.52750899607418, -57.99414941384282, -64....
# 28382  [[-20.826418293775916, -21.753312080806772, -2...
# 28383  [[-19.45033322403826, -18.135826656744467, -18...
#
# [28384 rows x 1 columns]

# %%
all_mel_data.to_csv("mel_dataset_1second.csv",index=False)

# %% [markdown]
# ## Labeling

# %%
all_audio_data = pd.DataFrame(columns = ['Audio', 'label'])
carhorn_data = pd.DataFrame(columns = ['Audio', 'label'])
siren_data = pd.DataFrame(columns = ['Audio', 'label'])
noise_data = pd.DataFrame(columns = ['Audio', 'label'])
humanvoice_data = pd.DataFrame(columns = ['Audio', 'label'])

carhorn_label = []
siren_label = []
noise_label = []
humanvoice_label = []
for i in range(len(carhorn)):
    carhorn_label.append('car horn')
for i in range(len(Siren)):
    siren_label.append('siren')
for i in range(len(noise)):
    noise_label.append('noise')
for i in range(len(humanvoice)):
    humanvoice_label.append('human voice')

carhorn_data['label'] = carhorn_label
siren_data['label'] = siren_label
noise_data['label'] = noise_label
humanvoice_data['label'] = humanvoice_label

for i in range(len(carhorn)):
    carhorn_data['Audio'][i] = carhorn[i]
for i in range(len(Siren)):
    siren_data['Audio'][i] = Siren[i]
for i in range(len(noise)):
    noise_data['Audio'][i] = noise[i]
for i in range(len(humanvoice)):
    humanvoice_data['Audio'][i] = humanvoice[i]
noise_data = noise_data.drop(index = [11938,20562,23821])
noise_data.reset_index(drop = True, inplace = True)

# %%
all_audio_data = pd.DataFrame(columns = ['Audio', 'label'])
all_audio_data = pd.concat([all_audio_data,carhorn_data,siren_data,noise_data,humanvoice_data])
all_audio_data.reset_index(drop = True, inplace = True)

# %%
all_audio_data
# Out:
#                                                    Audio        label
# 0      [-0.1864013671875, -0.17596435546875, -0.16668...     car horn
# 1      [-0.172149658203125, -0.16973876953125, -0.169...     car horn
# 2      [0.09576416015625, 0.093902587890625, 0.094635...     car horn
# 3      [0.1875, 0.17987060546875, 0.1741943359375, 0....     car horn
# 4      [0.081756591796875, 0.08306884765625, 0.083282...     car horn
# ...                                                  ...          ...
# 28382  [-9.709649020805955e-05, -0.000150483334437012...  human voice
# 28383  [0.024628236889839172, 0.02545403130352497, 0....  human voice
# 28384  [-0.00014931810437701643, -0.00016395644342992...  human voice
# 28385  [0.014613893814384937, 0.01496158167719841, 0....  human voice
# 28386  [-0.12411323189735413, -0.13137546181678772, -...  human voice
#
# [28387 rows x 2 columns]

# %%
all_audio_data.to_csv("labeled_dataset_1second.csv",index = False)

# %% [markdown]
# ## input log melspectrogram data & label data

# %%
noise_mel_list = noise_mel
noise_mel_list.pop(11938)
noise_mel_list.pop(20562)
noise_mel_list.pop(23821)
# Out:
# array([[-16.87106375,  -0.52693608,  -0.83878025, ...,  -4.10741456,
#          -9.00110039,  -3.38303493],
#        [-12.2679798 ,  -5.54796816,  -9.08412019, ..., -15.50358421,
#          -9.07262973, -12.72983984],
#        [-20.38476209, -20.78614707, -14.33883538, ..., -27.44196159,
#         -14.61906945, -10.20491666],
#        ...,
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ],
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ],
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ]])

# %%
all_mel = carhorn_mel+Siren_mel+noise_mel_list+humanvoice_mel
np_all_mel = np.array(all_mel)

# %%
np.save("all_mel",np_all_mel)

# %%
label_data = all_audio_data['label']

# %%
for i in range(len(label_data)):
    if label_data[i] == 'car horn':
        label_data[i] = 0
    elif label_data[i] == 'siren':
        label_data[i] = 1
    elif label_data[i] == 'noise':
        label_data[i] = 2
    elif label_data[i] == 'human voice':
        label_data[i] = 3

# %%
label_data = np.array(label_data)

# %%
label_data
# Out:
# array([0, 0, 0, ..., 3, 3, 3], dtype=object)

# %%
np.save("label_data",label_data)
